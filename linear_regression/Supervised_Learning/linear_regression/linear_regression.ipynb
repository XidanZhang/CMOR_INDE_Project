# %%
from sklearn.datasets import make_regression
import pandas as pd

# 生成回归数据
X, y = make_regression(n_samples=100, n_features=1, noise=10, random_state=42)

# 保存数据为 CSV 文件
df = pd.DataFrame(X, columns=["Feature"])
df["Target"] = y
df.to_csv("linear_regression_dataset.csv", index=False)

print("Dataset saved as linear_regression_dataset.csv")
# Out:
# Dataset saved as linear_regression_dataset.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 加载数据
data = pd.read_csv("linear_regression_dataset.csv")
X = data["Feature"].values
y = data["Target"].values

# 增加一个列向量用于偏置项
X_b = np.c_[np.ones((X.shape[0], 1)), X]

# 正规方程解线性回归
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# 预测
y_pred = X_b.dot(theta_best)

# 可视化
plt.scatter(X, y, color="blue", label="Actual")
plt.plot(X, y_pred, color="red", label="Predicted")
plt.xlabel("Feature")
plt.ylabel("Target")
plt.legend()
plt.title("Linear Regression Fit")
plt.show()

print(f"Model parameters: Intercept = {theta_best[0]}, Slope = {theta_best[1]}")
# Out:
# Model parameters: Intercept = 1.1651153205269726, Slope = 44.437169992254994
